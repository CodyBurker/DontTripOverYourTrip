# %%
tuning_config = "DeepFM_nofeature_tuner_config"

# %%
# !rm benchmarks/$tuning_config".csv" &> /dev/null
# !rm -rf models/$tuning_config"*" &> /dev/null
# !rm -rf data/$tuning_config"*" &> /dev/null
# !cd benchmarks; nohup python run_param_tuner.py --config ./tuner_config/DeepFM_nofeature_tuner_config.yaml --gpu 0 > run_nofeature.log
# Out:
# rm: cannot remove 'benchmarks/DeepFM_nofeature_tuner_config.csv': No such file or directory
# nohup: ignoring input and redirecting stderr to stdout

# %%
import pandas as pd

# %%
experiments = pd.read_csv("benchmarks/DeepFM_nofeature_tuner_config.csv", names=["time", "reproducing command", "expid", "dataset_id", "train", "validation"])
experiments
# Out:
#                 time                                reproducing command  \
# 0    20221022-065704  [command] python run_expid.py --version pytorc...
# 1    20221022-065734  [command] python run_expid.py --version pytorc...
# 2    20221022-065806  [command] python run_expid.py --version pytorc...
# 3    20221022-065840  [command] python run_expid.py --version pytorc...
# 4    20221022-065907  [command] python run_expid.py --version pytorc...
# 5    20221022-065936  [command] python run_expid.py --version pytorc...
# 6    20221022-070008  [command] python run_expid.py --version pytorc...
# 7    20221022-070037  [command] python run_expid.py --version pytorc...
# 8    20221022-070120  [command] python run_expid.py --version pytorc...
# 9    20221022-070159  [command] python run_expid.py --version pytorc...
# 10   20221022-070248  [command] python run_expid.py --version pytorc...
# 11   20221022-070329  [command] python run_expid.py --version pytorc...
# 12   20221022-070445  [command] python run_expid.py --version pytorc...
# 13   20221022-070550  [command] python run_expid.py --version pytorc...
# 14   20221022-070654  [command] python run_expid.py --version pytorc...
# 15   20221022-070749  [command] python run_expid.py --version pytorc...
#
#                                            expid  \
# 0   [exp_id] DeepFM_yelp_no_feature_001_c4d8d560
# 1   [exp_id] DeepFM_yelp_no_feature_002_5894b0e3
# 2   [exp_id] DeepFM_yelp_no_feature_003_872d8bf1
# 3   [exp_id] DeepFM_yelp_no_feature_004_75d98b21
# 4   [exp_id] DeepFM_yelp_no_feature_005_4e6db415
# 5   [exp_id] DeepFM_yelp_no_feature_006_b4d6abb6
# 6   [exp_id] DeepFM_yelp_no_feature_007_ea6736dc
# 7   [exp_id] DeepFM_yelp_no_feature_008_97e72897
# 8   [exp_id] DeepFM_yelp_no_feature_009_819baa8d
# 9   [exp_id] DeepFM_yelp_no_feature_010_94bf40f2
# 10  [exp_id] DeepFM_yelp_no_feature_011_5fe39b7b
# 11  [exp_id] DeepFM_yelp_no_feature_012_ad4e16bc
# 12  [exp_id] DeepFM_yelp_no_feature_013_14edc303
# 13  [exp_id] DeepFM_yelp_no_feature_014_31bc8f03
# 14  [exp_id] DeepFM_yelp_no_feature_015_8d7237a7
# 15  [exp_id] DeepFM_yelp_no_feature_016_fbdc55c7
#
#                                dataset_id  \
# 0   [dataset_id] yelp_no_feature_3d3ae056
# 1   [dataset_id] yelp_no_feature_3d3ae056
# 2   [dataset_id] yelp_no_feature_3d3ae056
# 3   [dataset_id] yelp_no_feature_3d3ae056
# 4   [dataset_id] yelp_no_feature_3d3ae056
# 5   [dataset_id] yelp_no_feature_3d3ae056
# 6   [dataset_id] yelp_no_feature_3d3ae056
# 7   [dataset_id] yelp_no_feature_3d3ae056
# 8   [dataset_id] yelp_no_feature_3d3ae056
# 9   [dataset_id] yelp_no_feature_3d3ae056
# 10  [dataset_id] yelp_no_feature_3d3ae056
# 11  [dataset_id] yelp_no_feature_3d3ae056
# 12  [dataset_id] yelp_no_feature_3d3ae056
# 13  [dataset_id] yelp_no_feature_3d3ae056
# 14  [dataset_id] yelp_no_feature_3d3ae056
# 15  [dataset_id] yelp_no_feature_3d3ae056
#
#                                         train  \
# 0   [train] logloss: 0.462677 - AUC: 0.838497
# 1   [train] logloss: 0.468721 - AUC: 0.837734
# 2   [train] logloss: 0.458991 - AUC: 0.841284
# 3   [train] logloss: 0.471646 - AUC: 0.830331
# 4   [train] logloss: 0.464105 - AUC: 0.835809
# 5   [train] logloss: 0.460404 - AUC: 0.839602
# 6   [train] logloss: 0.464246 - AUC: 0.835583
# 7   [train] logloss: 0.460570 - AUC: 0.839072
# 8   [train] logloss: 0.518446 - AUC: 0.769852
# 9   [train] logloss: 0.503758 - AUC: 0.792268
# 10  [train] logloss: 0.510343 - AUC: 0.780610
# 11  [train] logloss: 0.506070 - AUC: 0.790148
# 12  [train] logloss: 0.431950 - AUC: 0.858612
# 13  [train] logloss: 0.450930 - AUC: 0.841394
# 14  [train] logloss: 0.460927 - AUC: 0.831406
# 15  [train] logloss: 0.460563 - AUC: 0.832851
#
#                                  validation
# 0   [val] logloss: 0.539504 - AUC: 0.735648
# 1   [val] logloss: 0.543729 - AUC: 0.729113
# 2   [val] logloss: 0.540330 - AUC: 0.735822
# 3   [val] logloss: 0.543824 - AUC: 0.727937
# 4   [val] logloss: 0.533254 - AUC: 0.743556
# 5   [val] logloss: 0.534174 - AUC: 0.742810
# 6   [val] logloss: 0.533178 - AUC: 0.743600
# 7   [val] logloss: 0.534298 - AUC: 0.742757
# 8   [val] logloss: 0.552382 - AUC: 0.715255
# 9   [val] logloss: 0.551270 - AUC: 0.718637
# 10  [val] logloss: 0.550206 - AUC: 0.719205
# 11  [val] logloss: 0.553096 - AUC: 0.718158
# 12  [val] logloss: 0.544099 - AUC: 0.736737
# 13  [val] logloss: 0.541979 - AUC: 0.737379
# 14  [val] logloss: 0.540309 - AUC: 0.738543
# 15  [val] logloss: 0.540558 - AUC: 0.737747

# %%
experiments.iloc[4]["reproducing command"]
# Out:
# '[command] python run_expid.py --version pytorch --config ./tuner_config/DeepFM_nofeature_tuner_config --expid DeepFM_yelp_no_feature_005_4e6db415 --gpu 0'
