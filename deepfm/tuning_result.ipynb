# %%
import pandas as pd
import yaml

# %%
def get_model_spec(job_name):
    file_path = f"benchmarks/tuner_config/{job_name}_tuner_config/model_config.yaml"
    with open(file_path) as file:
        models_list = yaml.load(file, Loader=yaml.FullLoader)
        df_specs = pd.DataFrame.from_dict(models_list, orient="index")
        col_names = ["batch_norm", "hidden_units", "embedding_dim", "embedding_regularizer", "learning_rate", "net_dropout"]
        df_specs = df_specs[col_names]
    return df_specs
model_feature_specs = get_model_spec("DeepFM_feature")

# %%
def read_exp(job_name):
    file_path = f"benchmarks/{job_name}_tuner_config.csv"
    df_exp = pd.read_csv(file_path, 
                         names=["time", "reproducing command", "expid", "dataset_id", "train", "validation"])
    df_exp["val_auc"] = df_exp.validation.str.extractall(r'([0-9]\.\d+)').xs(1, level="match").astype("float")
    df_exp["expid"] = df_exp["expid"].str.split().str[1]
    df_exp = df_exp[["expid", "train", "validation", "val_auc"]]
    df_specs = get_model_spec(job_name)
    df_exp = df_exp.merge(df_specs, left_on="expid", right_index=True, how="left")
    return df_exp
def find_best_model(df_exp):
    return df_exp.loc[df_exp["val_auc"].idxmax()]

# %%
feature_exp = read_exp("DeepFM_feature")
nofeature_exp = read_exp("DeepFM_nofeature")

# %%
print("Best model with no feature data:")
find_best_model(nofeature_exp)
# Out:
# Best model with no feature data:
# expid                          DeepFM_yelp_no_feature_001_c064a006
# train                    [train] logloss: 0.460143 - AUC: 0.844091
# validation                 [val] logloss: 0.533441 - AUC: 0.743259
# val_auc                                                   0.743259
# batch_norm                                                   False
# hidden_units                                       [400, 400, 400]
# embedding_dim                                                   64
# embedding_regularizer                                          0.0
# learning_rate                                                0.001
# net_dropout                                                    0.0
# Name: 0, dtype: object

# %%
print("Best model with feature data:")
find_best_model(feature_exp)
# Out:
# Best model with feature data:
# expid                             DeepFM_yelp_feature_015_e310373d
# train                    [train] logloss: 3.394628 - AUC: 0.683488
# validation                 [val] logloss: 3.410920 - AUC: 0.684168
# val_auc                                                   0.684168
# batch_norm                                                   False
# hidden_units                                       [400, 400, 400]
# embedding_dim                                                  256
# embedding_regularizer                                         0.01
# learning_rate                                                0.001
# net_dropout                                                    0.0
# Name: 14, dtype: object

# %%
feature_exp
# Out:
#                                expid  \
# 0   DeepFM_yelp_feature_001_03e4b53d
# 1   DeepFM_yelp_feature_002_7f85efa5
# 2   DeepFM_yelp_feature_003_b71ca503
# 3   DeepFM_yelp_feature_004_da66f817
# 4   DeepFM_yelp_feature_005_2972f7f5
# 5   DeepFM_yelp_feature_006_9adf532d
# 6   DeepFM_yelp_feature_007_b53f1478
# 7   DeepFM_yelp_feature_008_762e09c2
# 8   DeepFM_yelp_feature_009_ed30b5fa
# 9   DeepFM_yelp_feature_010_6ae2c020
# 10  DeepFM_yelp_feature_011_92f14768
# 11  DeepFM_yelp_feature_012_817587a4
# 12  DeepFM_yelp_feature_013_13d3f7c2
# 13  DeepFM_yelp_feature_014_9f450893
# 14  DeepFM_yelp_feature_015_e310373d
# 15  DeepFM_yelp_feature_016_c64c11a6
# 16  DeepFM_yelp_feature_017_eeb63b8d
# 17  DeepFM_yelp_feature_018_8ec8411f
# 18  DeepFM_yelp_feature_019_41ac4806
# 19  DeepFM_yelp_feature_020_4e72011b
# 20  DeepFM_yelp_feature_021_8a22560d
# 21  DeepFM_yelp_feature_022_7c214c53
# 22  DeepFM_yelp_feature_023_f4f3e532
# 23  DeepFM_yelp_feature_024_1c257271
#
#                                          train  \
# 0    [train] logloss: 4.992003 - AUC: 0.500000
# 1    [train] logloss: 4.992003 - AUC: 0.500000
# 2    [train] logloss: 3.591318 - AUC: 0.659805
# 3    [train] logloss: 4.992003 - AUC: 0.500000
# 4    [train] logloss: 4.992003 - AUC: 0.500000
# 5    [train] logloss: 4.992003 - AUC: 0.500000
# 6    [train] logloss: 4.992003 - AUC: 0.500000
# 7    [train] logloss: 4.992003 - AUC: 0.500000
# 8    [train] logloss: 4.992003 - AUC: 0.500000
# 9    [train] logloss: 4.992003 - AUC: 0.500000
# 10   [train] logloss: 4.992003 - AUC: 0.500000
# 11   [train] logloss: 4.992003 - AUC: 0.500000
# 12   [train] logloss: 4.992003 - AUC: 0.500000
# 13   [train] logloss: 4.992003 - AUC: 0.500000
# 14   [train] logloss: 3.394628 - AUC: 0.683488
# 15   [train] logloss: 4.992003 - AUC: 0.500000
# 16   [train] logloss: 4.992003 - AUC: 0.500000
# 17   [train] logloss: 3.205235 - AUC: 0.685170
# 18   [train] logloss: 4.992003 - AUC: 0.500000
# 19   [train] logloss: 4.992003 - AUC: 0.500000
# 20   [train] logloss: 4.992003 - AUC: 0.500000
# 21   [train] logloss: 4.992003 - AUC: 0.500000
# 22   [train] logloss: 4.992003 - AUC: 0.500000
# 23  [train] logloss: 11.126093 - AUC: 0.500000
#
#                                   validation   val_auc  batch_norm  \
# 0    [val] logloss: 4.997136 - AUC: 0.500000  0.500000       False
# 1    [val] logloss: 4.997136 - AUC: 0.500000  0.500000       False
# 2    [val] logloss: 3.755078 - AUC: 0.650685  0.650685       False
# 3    [val] logloss: 4.997136 - AUC: 0.500000  0.500000       False
# 4    [val] logloss: 4.997136 - AUC: 0.500000  0.500000       False
# 5    [val] logloss: 4.997136 - AUC: 0.500000  0.500000       False
# 6    [val] logloss: 4.997136 - AUC: 0.500000  0.500000       False
# 7    [val] logloss: 4.997136 - AUC: 0.500000  0.500000       False
# 8    [val] logloss: 4.997136 - AUC: 0.500000  0.500000       False
# 9    [val] logloss: 4.997136 - AUC: 0.500000  0.500000       False
# 10   [val] logloss: 4.997136 - AUC: 0.500000  0.500000       False
# 11   [val] logloss: 4.997136 - AUC: 0.500000  0.500000       False
# 12   [val] logloss: 4.997136 - AUC: 0.500000  0.500000       False
# 13   [val] logloss: 4.997136 - AUC: 0.500000  0.500000       False
# 14   [val] logloss: 3.410920 - AUC: 0.684168  0.684168       False
# 15   [val] logloss: 4.997136 - AUC: 0.500000  0.500000       False
# 16   [val] logloss: 4.997136 - AUC: 0.500000  0.500000       False
# 17   [val] logloss: 3.248633 - AUC: 0.683407  0.683407       False
# 18   [val] logloss: 4.997136 - AUC: 0.500000  0.500000       False
# 19   [val] logloss: 4.997136 - AUC: 0.500000  0.500000       False
# 20   [val] logloss: 4.997136 - AUC: 0.500000  0.500000       False
# 21   [val] logloss: 4.997136 - AUC: 0.500000  0.500000       False
# 22   [val] logloss: 4.997136 - AUC: 0.500000  0.500000       False
# 23  [val] logloss: 11.120960 - AUC: 0.500000  0.500000       False
#
#        hidden_units  embedding_dim  embedding_regularizer  learning_rate  \
# 0   [400, 400, 400]             64                   0.00          0.001
# 1   [400, 400, 400]            128                   0.00          0.001
# 2   [400, 400, 400]            256                   0.00          0.001
# 3   [400, 400, 400]             64                   0.00          0.001
# 4   [400, 400, 400]            128                   0.00          0.001
# 5   [400, 400, 400]            256                   0.00          0.001
# 6   [400, 400, 400]             64                   0.00          0.010
# 7   [400, 400, 400]            128                   0.00          0.010
# 8   [400, 400, 400]            256                   0.00          0.010
# 9   [400, 400, 400]             64                   0.00          0.010
# 10  [400, 400, 400]            128                   0.00          0.010
# 11  [400, 400, 400]            256                   0.00          0.010
# 12  [400, 400, 400]             64                   0.01          0.001
# 13  [400, 400, 400]            128                   0.01          0.001
# 14  [400, 400, 400]            256                   0.01          0.001
# 15  [400, 400, 400]             64                   0.01          0.001
# 16  [400, 400, 400]            128                   0.01          0.001
# 17  [400, 400, 400]            256                   0.01          0.001
# 18  [400, 400, 400]             64                   0.01          0.010
# 19  [400, 400, 400]            128                   0.01          0.010
# 20  [400, 400, 400]            256                   0.01          0.010
# 21  [400, 400, 400]             64                   0.01          0.010
# 22  [400, 400, 400]            128                   0.01          0.010
# 23  [400, 400, 400]            256                   0.01          0.010
#
#     net_dropout
# 0          0.00
# 1          0.00
# 2          0.00
# 3          0.03
# 4          0.03
# 5          0.03
# 6          0.00
# 7          0.00
# 8          0.00
# 9          0.03
# 10         0.03
# 11         0.03
# 12         0.00
# 13         0.00
# 14         0.00
# 15         0.03
# 16         0.03
# 17         0.03
# 18         0.00
# 19         0.00
# 20         0.00
# 21         0.03
# 22         0.03
# 23         0.03

# %%
feature_exp[feature_exp.val_auc > 0.55]
# Out:
#                                expid  \
# 2   DeepFM_yelp_feature_003_b71ca503
# 14  DeepFM_yelp_feature_015_e310373d
# 17  DeepFM_yelp_feature_018_8ec8411f
#
#                                         train  \
# 2   [train] logloss: 3.591318 - AUC: 0.659805
# 14  [train] logloss: 3.394628 - AUC: 0.683488
# 17  [train] logloss: 3.205235 - AUC: 0.685170
#
#                                  validation   val_auc  batch_norm  \
# 2   [val] logloss: 3.755078 - AUC: 0.650685  0.650685       False
# 14  [val] logloss: 3.410920 - AUC: 0.684168  0.684168       False
# 17  [val] logloss: 3.248633 - AUC: 0.683407  0.683407       False
#
#        hidden_units  embedding_dim  embedding_regularizer  learning_rate  \
# 2   [400, 400, 400]            256                   0.00          0.001
# 14  [400, 400, 400]            256                   0.01          0.001
# 17  [400, 400, 400]            256                   0.01          0.001
#
#     net_dropout
# 2          0.00
# 14         0.00
# 17         0.03
